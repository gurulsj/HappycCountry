# %%
import pandas as p
import numpy as np
import warnings as w
w.filterwarnings('ignore')

# %%
happy=p.read_csv("Downloads\happiness_score_dataset.csv")
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happy.shape
# Out:
# (158, 12)

# %%
happy.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
happy.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
happy['Country']
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# 157           Togo
# Name: Country, Length: 158, dtype: object

# %%
happy['Happiness Rank'].mode()
# Out:
# 0    82
# Name: Happiness Rank, dtype: int64

# %%
# happy['Happiness Score']=happy['Happyness Score'].astype(int)

# %%
happy.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %%
happy.value_counts()
# Out:
# Country                  Region                           Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  Family   Health (Life Expectancy)  Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual
# Afghanistan              Southern Asia                    153             3.575            0.03084         0.31982                   0.30285  0.30335                   0.23414  0.09719                        0.36510     1.95210              1
# Palestinian Territories  Middle East and Northern Africa  108             4.715            0.04394         0.59867                   0.92558  0.66015                   0.24499  0.12905                        0.11251     2.04384              1
# Nicaragua                Latin America and Caribbean      57              5.828            0.05371         0.59325                   1.14184  0.74314                   0.55475  0.19317                        0.27815     2.32407              1
# ...

# %%
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happy[happy['Region']=='Western Europe']
# Out:
#             Country          Region  Happiness Rank  Happiness Score  \
# 0       Switzerland  Western Europe               1            7.587
# 1           Iceland  Western Europe               2            7.561
# 2           Denmark  Western Europe               3            7.527
# 3            Norway  Western Europe               4            7.522
# 5           Finland  Western Europe               6            7.406
# 6       Netherlands  Western Europe               7            7.378
# 7            Sweden  Western Europe               8            7.364
# 12          Austria  Western Europe              13            7.200
# 16       Luxembourg  Western Europe              17            6.946
# 17          Ireland  Western Europe              18            6.940
# 18          Belgium  Western Europe              19            6.937
# 20   United Kingdom  Western Europe              21            6.867
# 25          Germany  Western Europe              26            6.750
# ...

# %%
happy.iloc[:,6:7].head(10)
# Out:
#     Family
# 0  1.34951
# 1  1.40223
# 2  1.36058
# 3  1.33095
# 4  1.32261
# 5  1.31826
# 6  1.28017
# 7  1.28907
# 8  1.31967
# 9  1.30923

# %%
happy.index=happy.index+1

# %%
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 1    Switzerland                   Western Europe               1
# 2        Iceland                   Western Europe               2
# 3        Denmark                   Western Europe               3
# 4         Norway                   Western Europe               4
# 5         Canada                    North America               5
# ..           ...                              ...             ...
# 154       Rwanda               Sub-Saharan Africa             154
# 155        Benin               Sub-Saharan Africa             155
# 156        Syria  Middle East and Northern Africa             156
# 157      Burundi               Sub-Saharan Africa             157
# 158         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happi=[]
for i in happy['Happiness Score']:
    if i<7:
        happi.append(i)

# %%
j=p.DataFrame(happi)

# %%
j
# Out:
#          0
# 0    6.983
# 1    6.946
# 2    6.940
# 3    6.937
# 4    6.901
# ..     ...
# 138  3.465
# 139  3.340
# 140  3.006
# 141  2.905
# 142  2.839
#
# [143 rows x 1 columns]

# %%
j.rename(columns={0:'Happy Score'},inplace=True)

# %%
j
# Out:
#      Happy Score
# 0          6.983
# 1          6.946
# 2          6.940
# 3          6.937
# 4          6.901
# ..           ...
# 138        3.465
# 139        3.340
# 140        3.006
# 141        2.905
# 142        2.839
#
# [143 rows x 1 columns]

# %%
i=happy['Happiness Score']<7
i=p.DataFrame(i)
i
# Out:
#      Happiness Score
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# ..               ...
# 154             True
# 155             True
# 156             True
# 157             True
# 158             True
#
# [158 rows x 1 columns]

# %%
happy.loc[0:5,['Happiness Rank','Country']]
# Out:
#    Happiness Rank      Country
# 1               1  Switzerland
# 2               2      Iceland
# 3               3      Denmark
# 4               4       Norway
# 5               5       Canada

# %%
i=p.DataFrame(happy[['Happiness Rank','Country']])

# %%
i
# Out:
#      Happiness Rank      Country
# 1                 1  Switzerland
# 2                 2      Iceland
# 3                 3      Denmark
# 4                 4       Norway
# 5                 5       Canada
# ..              ...          ...
# 154             154       Rwanda
# 155             155        Benin
# 156             156        Syria
# 157             157      Burundi
# 158             158         Togo
#
# [158 rows x 2 columns]

# %%
happy.reset_index(inplace=True)

# %%
hh

# %%
happy.rename(columns={'unnamed': 's.no'}, inplace=True)

# %%
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 1    Switzerland                   Western Europe               1
# 2        Iceland                   Western Europe               2
# 3        Denmark                   Western Europe               3
# 4         Norway                   Western Europe               4
# 5         Canada                    North America               5
# ..           ...                              ...             ...
# 154       Rwanda               Sub-Saharan Africa             154
# 155        Benin               Sub-Saharan Africa             155
# 156        Syria  Middle East and Northern Africa             156
# 157      Burundi               Sub-Saharan Africa             157
# 158         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happy['Freedom'].mode()
# Out:
# 0      0.00000
# 1      0.07699
# 2      0.09245
# 3      0.10081
# 4      0.10384
#         ...
# 153    0.65821
# 154    0.65980
# 155    0.66246
# 156    0.66557
# 157    0.66973
# Name: Freedom, Length: 158, dtype: float64

# %%
happy=happy.drop(158)

# %%
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 1    Switzerland                   Western Europe               1
# 2        Iceland                   Western Europe               2
# 3        Denmark                   Western Europe               3
# 4         Norway                   Western Europe               4
# 5         Canada                    North America               5
# ..           ...                              ...             ...
# 153  Afghanistan                    Southern Asia             153
# 154       Rwanda               Sub-Saharan Africa             154
# 155        Benin               Sub-Saharan Africa             155
# 156        Syria  Middle East and Northern Africa             156
# 157      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happy['presidant']=np.nan

# %%
happy.loc[1,'presidant']='Viola Amherd'

# %%
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 1    Switzerland                   Western Europe               1
# 2        Iceland                   Western Europe               2
# 3        Denmark                   Western Europe               3
# 4         Norway                   Western Europe               4
# 5         Canada                    North America               5
# ..           ...                              ...             ...
# 153  Afghanistan                    Southern Asia             153
# 154       Rwanda               Sub-Saharan Africa             154
# 155        Benin               Sub-Saharan Africa             155
# 156        Syria  Middle East and Northern Africa             156
# 157      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.587         0.03411                   1.39651  1.34951
# ...

# %%
new={'Country': 'india',
    'Region': 'south region',
    'Happiness Rank': 999,
    'Happiness Score': 5.000,
    'Standard Error': 0.05000,
    'Economy (GDP per Capita)': 0.80000,
    'Family': 1.20000,
    'Health (Life Expectancy)': 0.75000,
    'Freedom': 0.60000,
    'Trust (Government Corruption)': 0.20000,
    'Generosity': 0.10000,
    'Dystopia Residual': 1.50000,
    'presidant': np.nan }

# %%
happy['Region'].value_counts()
# Out:
# Region
# Sub-Saharan Africa                 39
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
happy
# Out:
#          Country                           Region  Happiness Rank  \
# 1    Switzerland                   Western Europe               1
# 2        Iceland                   Western Europe               2
# 3        Denmark                   Western Europe               3
# 4         Norway                   Western Europe               4
# 5         Canada                    North America               5
# ..           ...                              ...             ...
# 153  Afghanistan                    Southern Asia             153
# 154       Rwanda               Sub-Saharan Africa             154
# 155        Benin               Sub-Saharan Africa             155
# 156        Syria  Middle East and Northern Africa             156
# 157      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happy.to_csv('happy.csv')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\guru'
